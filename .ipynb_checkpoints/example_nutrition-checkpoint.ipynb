# %% [markdown]
# ## Preface

# %% [markdown]
# First, load relevant dataset:

# %%
# !pip install CFEDemands
import cfe

r = cfe.from_dataset('./TanzanianNPS/tanzanian_nps.ds')
# Out:
# Requirement already satisfied: CFEDemands in /srv/app/venv/lib/python3.6/site-packages

# %% [markdown]
# Also, choose reference prices:

# %%
x = 10690 # Budget

# Note selection of prices for 2008 for market 1
p = r.prices.sel(t=2008,m=1).copy()

p.to_dataframe().fillna(1).squeeze()
# Out:
#                                                        t  m       prices
# i
# Beef Including Minced Sausage                       2008  1  2600.000000
# Bottled/Canned Soft Drinks (Soda, Juice, Water)     2008  1     1.142857
# Bread                                               2008  1     1.500000
# Buns, Cakes And Biscuits                            2008  1     1.666667
# Cassava Fresh                                       2008  1     5.000000
# Chicken And Other Poultry                           2008  1     6.000000
# Citrus Fruits (Oranges, Lemon, Tangerines, Etc.)    2008  1     0.666667
# Coconuts (Mature/Immature)                          2008  1     0.681818
# Cooking Bananas, Plantains                          2008  1     0.976190
# Cooking Oil                                         2008  1     2.545455
# Dried/Salted/Canned Fish And Seafood (Incl. Dagaa)  2008  1     2.500000
# Eggs                                                2008  1   200.000000
# Fresh Fish And Seafood (Including Dagaa)            2008  1     3.333333
# Fresh Milk                                          2008  1   500.000000
# Goat Meat                                           2008  1  2000.000000
# Groundnuts In Shell/Shelled                         2008  1     1.400000
# Honey, Syrups, Jams, Marmalade, Jellies, Canned...  2008  1     3.633333
# Irish Potatoes                                      2008  1   500.000000
# Macaroni, Spaghetti                                 2008  1     2.400000
# Maize (Flour)                                       2008  1   600.000000
# Mangoes, Avocadoes And Other Fruits                 2008  1     0.750000
# Milk Products (Like Cream, Cheese, Yoghurt Etc)     2008  1   400.000000
# Millet And Sorghum (Flour)                          2008  1   600.000000
# Onions, Tomatoes, Carrots And Green Pepper, Oth...  2008  1     1.000000
# Other Spices                                        2008  1     2.000000
# Peas, Beans, Lentils And Other Pulses               2008  1   600.000000
# Rice (Husked)                                       2008  1  1000.000000
# Ripe Bananas                                        2008  1     0.833333
# Salt                                                2008  1     0.700000
# Spinach, Cabbage And Other Green Vegetables         2008  1     0.666667
# Sugar                                               2008  1     2.600000
# Sugarcane                                           2008  1     0.600000
# Sweet Potatoes                                      2008  1     0.952381
# Sweets                                              2008  1    15.000000
# Tea Dry                                             2008  1     6.666667
# Yams/Cocoyams                                       2008  1     1.000000

# %% [markdown]
# And with $(x,p)$ defined we can calculate example demands:

# %%
c=r.demands(x,p)
c
# Out:
# i
# Beef Including Minced Sausage                                  0.069502
# Bottled/Canned Soft Drinks (Soda, Juice, Water)              471.323983
# Bread                                                         71.508434
# Buns, Cakes And Biscuits                                     112.104706
# Cassava Fresh                                                  6.449252
# Chicken And Other Poultry                                     60.000869
# Citrus Fruits (Oranges, Lemon, Tangerines, Etc.)            1585.498606
# Coconuts (Mature/Immature)                                    93.910120
# Cooking Bananas, Plantains                                   197.061746
# Cooking Oil                                                   90.549566
# Dried/Salted/Canned Fish And Seafood (Incl. Dagaa)            63.733597
# Eggs                                                           0.503373
# Fresh Fish And Seafood (Including Dagaa)                     421.196561
# Fresh Milk                                                     0.076553
# Goat Meat                                                      0.078046
# Groundnuts In Shell/Shelled                                   17.414414
# Honey, Syrups, Jams, Marmalade, Jellies, Canned Fruits       118.632170
# Irish Potatoes                                                 0.142722
# Macaroni, Spaghetti                                           13.453057
# Maize (Flour)                                                  0.906691
# Mangoes, Avocadoes And Other Fruits                         1468.771563
# Milk Products (Like Cream, Cheese, Yoghurt Etc)                0.098800
# Millet And Sorghum (Flour)                                     0.456113
# Onions, Tomatoes, Carrots And Green Pepper, Other Viungo    1928.461596
# Other Spices                                                  25.214741
# Peas, Beans, Lentils And Other Pulses                          0.210354
# Rice (Husked)                                                  0.212106
# Ripe Bananas                                                 706.460571
# Salt                                                           1.666716
# Spinach, Cabbage And Other Green Vegetables                  397.712915
# Sugar                                                         11.650938
# Sugarcane                                                    102.202860
# Sweet Potatoes                                                17.610541
# Sweets                                                         2.014343
# Tea Dry                                                        2.160541
# Yams/Cocoyams                                                 38.947653
# Name: quantities, dtype: float64

# %% [markdown]
# Finally, define a function to change a single price in the vector $p$:

# %%
def my_prices(p0,p=p,i='Ripe Bananas'):
    p = p.copy()
    p.loc[i] = p0
    return p

# %% [markdown]
# ## Mapping to Nutrients

# %% [markdown]
# We&rsquo;ve seen how to map prices and budgets into vectors of consumption
# quantities using `cfe.Result.demands`.  Next we want to think about
# how to map these into bundles of *nutrients*.  The information needed
# for the mapping comes from a &ldquo;Food Conversion Table&rdquo; (or database,
# such as the [USDA Nutrition DataBase](https://ndb.nal.usda.gov/ndb/doc/apilist/API-FOOD-REPORTV2.md)).   Here we&rsquo;ve adapted (with
# thanks to Alessandro Tarozzi of the Universitat Pompeu Fabra) a food
# conversion table developed by Gopalan et al (1980) to the foods
# reported in the Indian ICRISAT data:

# %%
import pandas as pd
fct = pd.read_pickle('./TanzanianNPS/fct.df')

# Change some labels
d={'protein g':'Protein',
   'energy kcal':'Calories',
   'ca mg':'Calcium',
   'fe mg':'Iron',
   'zn mg': 'Zinc',
   'mg mg': 'Magnesium',
   'vit a ug':'Vitamin A',
  'vit e ug':'Vitamin E',
  'vit c mg':"Vitamin C",
  'vit b6 mg':'Vitamin B6',
   'vit b12 ug':'Vitamin B12'}

fct = fct.rename(columns=d)[list(d.values())]
#fct.index = fct.index.droplevel('unit')
fct = fct.rename(index={'Bread, white':'Bread'})
fct
# Out:
#                                                     Protein  Calories  \
# Item name
# Rice (Paddy)                                            6.5     358.0
# Rice (Husked) (white grain raw)                         6.5     358.0
# Maize (Green, Cob, immature)                            1.8      59.0
# Maize (Grain, dry, raw)                                 8.1     362.0
# Maize (Flour, dry)                                      8.1     362.0
# Millet and Sorghum (Grain)                              6.6     328.0
# Millet and Sorghum (Flour)                              6.6     328.0
# Bread                                                   8.0     274.0
# Cake                                                    4.7     320.0
# Macaroni (/Spaghetti)                                  10.5     371.0
# Other cereal products                                   NaN       NaN
# Cassava Fresh, raw                                      1.4     160.0
# Cassava dry/flour                                       2.6     314.0
# Sweet potatoes, fresh AP                                1.2      74.0
# Yams/cocoyams raw                                       2.1      97.0
# Irish potatoes, cooked (English)                        2.0      93.0
# Cooking bananas (/Plantains)                            NaN       NaN
# Other starches (edible)                                 0.3     381.0
# Sugar                                                   0.0     387.0
# Sweets (Candy, Chocolate)                               4.2     479.0
# Honey (/Syrups, jams, marmalade, jellies, canne...      0.3     304.0
# Lentil, cooked / Peas (/Beans, lentils and othe...      9.0     116.0
# Groundnuts in shell/shelled                            25.8     567.0
# Coconuts (mature/immature)                              0.5      70.0
# Cashew (Almonds and other nuts)                        20.0     589.0
# Sunflower seed / Seeds and products from nuts/s...     26.4     588.0
# Onion, raw (/tomatoes, carrots and green pepper...      1.3      40.0
# Spinach, cooked (/cabbage and other green veget...      3.0      23.0
# Amranth, leaves raw / Canned, dried and wild ve...      8.5      23.0
# Ripe Bananas                                            1.1      89.0
# Oranges (citrus fruits)                                 0.9      47.0
# Mangoes (other fruits)                                  0.5      65.0
# Sugarcane                                               0.0      26.0
# Goat meat                                              24.9     269.0
# Beef including minced sausage                          24.9     323.0
# Pork including sausages and bacon                      19.6     537.0
# Chicken and other poultry                              24.5     167.0
# Wild birds and insects                                  NaN       NaN
# Cricket (Other domestic/wild meat products)             9.6       7.5
# Eggs                                                   19.2     278.0
# Raw Fresh fish and seafood (including dagaa)           21.4     112.0
# Dried/salted/canned fish and seafood (including...     66.4     309.0
# Fish                                                   18.1      98.0
# Fresh milk                                              3.2      60.0
# Cream cheese (milk products)                            7.6     349.0
# Canned milk/milk powder                                26.3     496.0
# Cooking oil (vegetable oil)                             0.0     862.0
# Butter refined - ghee                                   0.3     876.0
# Salt                                                    0.0       0.0
# Other spices                                            NaN       NaN
# Wheat flour (whole grain)                              13.7     399.0
# Maida (wheat)                                          12.3     349.0
# Tea dry                                                 0.0       1.0
# Coffee and cocoa                                       10.0     200.0
# Other raw materials for drinks                          NaN       NaN
# Mango juice (soda, juice, water)                        0.2      54.0
# Instant coffee                                         10.0     200.0
# Bottled beer                                            0.3      41.0
# Local beer                                              0.3      41.0
# Vinegar (Wine and spirits)                              0.0      19.0
#
#                                                     Calcium  Iron  Zinc  \
# Item name
# Rice (Paddy)                                            8.0   0.6   1.1
# Rice (Husked) (white grain raw)                         8.0   0.6   1.1
# Maize (Green, Cob, immature)                            1.0   0.3   0.3
# Maize (Grain, dry, raw)                                 6.0   3.5   1.8
# Maize (Flour, dry)                                      6.0   3.5   1.8
# Millet and Sorghum (Grain)                            275.0   2.7   1.2
# Millet and Sorghum (Flour)                            275.0   2.7   1.2
# Bread                                                  10.0   0.5   0.9
# Cake                                                   38.0   0.4   0.4
# Macaroni (/Spaghetti)                                  15.0   1.2   0.1
# Other cereal products                                   NaN   NaN   NaN
# Cassava Fresh, raw                                     16.0   0.3   0.3
# Cassava dry/flour                                      46.0   1.9   0.7
# Sweet potatoes, fresh AP                               20.0   0.4   0.2
# Yams/cocoyams raw                                       8.0   0.8   0.5
# Irish potatoes, cooked (English)                        5.0   0.4   0.3
# Cooking bananas (/Plantains)                            NaN   NaN   NaN
# Other starches (edible)                                 2.0   0.5   0.1
# Sugar                                                   1.0   0.1   0.0
# Sweets (Candy, Chocolate)                              32.0   3.1   1.6
# Honey (/Syrups, jams, marmalade, jellies, canne...      6.0   0.4   0.2
# Lentil, cooked / Peas (/Beans, lentils and othe...     51.0   8.8   3.5
# Groundnuts in shell/shelled                            92.0   4.6   3.3
# Coconuts (mature/immature)                            126.0   0.4   0.1
# Cashew (Almonds and other nuts)                       266.0   3.7   2.9
# Sunflower seed / Seeds and products from nuts/s...    131.0   7.8  10.3
# Onion, raw (/tomatoes, carrots and green pepper...     23.0   0.2   0.2
# Spinach, cooked (/cabbage and other green veget...    136.0   3.6   0.8
# Amranth, leaves raw / Canned, dried and wild ve...     96.9   2.3   0.6
# Ripe Bananas                                            5.0   0.3   0.2
# Oranges (citrus fruits)                                40.0   0.1   0.1
# Mangoes (other fruits)                                 10.0   0.1   0.0
# Sugarcane                                               6.0   0.1   0.0
# Goat meat                                               4.0   1.7   4.1
# Beef including minced sausage                           4.0   1.7   4.1
# Pork including sausages and bacon                      18.0   0.8   2.1
# Chicken and other poultry                               9.0   1.0   1.3
# Wild birds and insects                                  NaN   NaN   NaN
# Cricket (Other domestic/wild meat products)            90.0   2.5   8.4
# Eggs                                                   96.0   5.9   2.1
# Raw Fresh fish and seafood (including dagaa)           48.0   0.9   0.4
# Dried/salted/canned fish and seafood (including...     41.0   1.4   1.7
# Fish                                                    7.0   0.3   0.3
# Fresh milk                                            115.0   0.0   0.0
# Cream cheese (milk products)                           80.0   1.2   0.5
# Canned milk/milk powder                               851.0   0.7   3.0
# Cooking oil (vegetable oil)                             0.0   0.0   0.0
# Butter refined - ghee                                   8.0   0.1   0.0
# Salt                                                   45.0   0.1   0.0
# Other spices                                            NaN   NaN   NaN
# Wheat flour (whole grain)                              15.0   1.2   0.7
# Maida (wheat)                                          26.0   2.8   2.0
# Tea dry                                                 2.0   0.0   0.0
# Coffee and cocoa                                      300.0  10.0   0.0
# Other raw materials for drinks                          NaN   NaN   NaN
# Mango juice (soda, juice, water)                        4.0   0.0   0.0
# Instant coffee                                        300.0  10.0   0.0
# Bottled beer                                            5.0   0.0   0.0
# Local beer                                              5.0   0.0   0.0
# Vinegar (Wine and spirits)                              8.0   0.4   0.1
#
#                                                     Magnesium  Vitamin A  \
# Item name
# Rice (Paddy)                                             36.0        0.0
# Rice (Husked) (white grain raw)                          36.0        0.0
# Maize (Green, Cob, immature)                             18.0        7.0
# Maize (Grain, dry, raw)                                 127.0        0.0
# Maize (Flour, dry)                                      127.0        0.0
# Millet and Sorghum (Grain)                               27.0        5.0
# Millet and Sorghum (Flour)                               27.0        5.0
# Bread                                                    27.0        0.0
# Cake                                                      9.0       34.0
# Macaroni (/Spaghetti)                                    22.0        0.0
# Other cereal products                                     NaN        NaN
# Cassava Fresh, raw                                       21.0        1.0
# Cassava dry/flour                                        24.0       14.0
# Sweet potatoes, fresh AP                                 14.0     1056.0
# Yams/cocoyams raw                                        26.0        0.0
# Irish potatoes, cooked (English)                         25.0        0.0
# Cooking bananas (/Plantains)                              NaN        NaN
# Other starches (edible)                                   3.0        0.0
# Sugar                                                     0.0        0.0
# Sweets (Candy, Chocolate)                               115.0        0.0
# Honey (/Syrups, jams, marmalade, jellies, canne...        2.0        0.0
# Lentil, cooked / Peas (/Beans, lentils and othe...       96.0        3.0
# Groundnuts in shell/shelled                             168.0        0.0
# Coconuts (mature/immature)                                3.0        0.0
# Cashew (Almonds and other nuts)                         296.0        0.0
# Sunflower seed / Seeds and products from nuts/s...      347.0        7.0
# Onion, raw (/tomatoes, carrots and green pepper...       10.0        0.0
# Spinach, cooked (/cabbage and other green veget...       87.0      819.0
# Amranth, leaves raw / Canned, dried and wild ve...       55.0      146.0
# Ripe Bananas                                             27.0        3.0
# Oranges (citrus fruits)                                  10.0        8.0
# Mangoes (other fruits)                                    9.0       38.0
# Sugarcane                                                 2.0        0.0
# Goat meat                                                23.0        0.0
# Beef including minced sausage                            23.0        0.0
# Pork including sausages and bacon                        17.0        1.0
# Chicken and other poultry                                14.0       27.0
# Wild birds and insects                                    NaN        NaN
# Cricket (Other domestic/wild meat products)              62.0        1.0
# Eggs                                                     26.0      810.0
# Raw Fresh fish and seafood (including dagaa)             86.0       43.0
# Dried/salted/canned fish and seafood (including...      122.0        0.0
# Fish                                                     21.0        0.0
# Fresh milk                                               12.0       28.0
# Cream cheese (milk products)                              6.0      366.0
# Canned milk/milk powder                                  81.0      407.0
# Cooking oil (vegetable oil)                               0.0        0.0
# Butter refined - ghee                                     1.0      925.0
# Salt                                                      2.0        0.0
# Other spices                                              NaN        NaN
# Wheat flour (whole grain)                                22.0        0.0
# Maida (wheat)                                            92.0        0.0
# Tea dry                                                   2.0        0.0
# Coffee and cocoa                                        400.0        0.0
# Other raw materials for drinks                            NaN        NaN
# Mango juice (soda, juice, water)                          4.0      168.0
# Instant coffee                                          400.0        0.0
# Bottled beer                                              6.0        0.0
# Local beer                                                6.0        0.0
# Vinegar (Wine and spirits)                               10.0        0.0
#
#                                                     Vitamin E  Vitamin C  \
# Item name
# Rice (Paddy)                                              0.0        0.0
# Rice (Husked) (white grain raw)                           0.0        0.0
# Maize (Green, Cob, immature)                              0.0        3.0
# Maize (Grain, dry, raw)                                   1.0        0.0
# Maize (Flour, dry)                                        1.0        0.0
# Millet and Sorghum (Grain)                                0.0        0.0
# Millet and Sorghum (Flour)                                0.0        0.0
# Bread                                                     0.0        0.0
# Cake                                                      1.0        0.0
# Macaroni (/Spaghetti)                                     0.0        0.0
# Other cereal products                                     NaN        NaN
# Cassava Fresh, raw                                        0.2       20.6
# Cassava dry/flour                                         0.0       72.0
# Sweet potatoes, fresh AP                                  4.0       18.0
# Yams/cocoyams raw                                         5.0       12.0
# Irish potatoes, cooked (English)                          6.7       18.6
# Cooking bananas (/Plantains)                              NaN        NaN
# Other starches (edible)                                   0.0        0.0
# Sugar                                                     0.0        0.0
# Sweets (Candy, Chocolate)                                 0.3        0.0
# Honey (/Syrups, jams, marmalade, jellies, canne...        0.0        1.0
# Lentil, cooked / Peas (/Beans, lentils and othe...        0.0        5.0
# Groundnuts in shell/shelled                               9.0        0.0
# Coconuts (mature/immature)                                0.0        1.0
# Cashew (Almonds and other nuts)                          24.0        1.0
# Sunflower seed / Seeds and products from nuts/s...        2.0        0.0
# Onion, raw (/tomatoes, carrots and green pepper...        0.0        7.4
# Spinach, cooked (/cabbage and other green veget...        1.0       10.0
# Amranth, leaves raw / Canned, dried and wild ve...        0.0       44.5
# Ripe Bananas                                              0.1        8.7
# Oranges (citrus fruits)                                   0.0       53.0
# Mangoes (other fruits)                                    1.1       27.7
# Sugarcane                                                 0.0        0.0
# Goat meat                                                 0.0        0.0
# Beef including minced sausage                             0.0        0.0
# Pork including sausages and bacon                         0.0        0.0
# Chicken and other poultry                                 0.0        0.0
# Wild birds and insects                                    NaN        NaN
# Cricket (Other domestic/wild meat products)               0.0        2.0
# Eggs                                                      2.0        0.0
# Raw Fresh fish and seafood (including dagaa)              1.0        0.0
# Dried/salted/canned fish and seafood (including...        4.0        0.0
# Fish                                                      0.0       17.0
# Fresh milk                                                0.1        0.0
# Cream cheese (milk products)                              0.3        0.0
# Canned milk/milk powder                                   0.0        7.0
# Cooking oil (vegetable oil)                               1.0        0.0
# Butter refined - ghee                                     3.0        0.0
# Salt                                                      0.0        0.0
# Other spices                                              NaN        NaN
# Wheat flour (whole grain)                                 0.0        0.0
# Maida (wheat)                                             1.0        0.0
# Tea dry                                                   0.0        0.0
# Coffee and cocoa                                          0.0        0.0
# Other raw materials for drinks                            NaN        NaN
# Mango juice (soda, juice, water)                          0.0       15.0
# Instant coffee                                            0.0        0.0
# Bottled beer                                              0.0        0.0
# Local beer                                                0.0        0.0
# Vinegar (Wine and spirits)                                0.0        0.5
#
#                                                     Vitamin B6  Vitamin B12
# Item name
# Rice (Paddy)                                               0.1          0.0
# Rice (Husked) (white grain raw)                            0.1          0.0
# Maize (Green, Cob, immature)                               0.0          0.0
# Maize (Grain, dry, raw)                                    0.3          0.0
# Maize (Flour, dry)                                         0.3          0.0
# Millet and Sorghum (Grain)                                 0.2          0.0
# Millet and Sorghum (Flour)                                 0.2          0.0
# Bread                                                      0.0          0.0
# Cake                                                       0.0          0.2
# Macaroni (/Spaghetti)                                      0.0          0.0
# Other cereal products                                      NaN          NaN
# Cassava Fresh, raw                                         0.1          0.0
# Cassava dry/flour                                          0.7          0.0
# Sweet potatoes, fresh AP                                   0.2          0.0
# Yams/cocoyams raw                                          0.2          0.0
# Irish potatoes, cooked (English)                           0.7          0.0
# Cooking bananas (/Plantains)                               NaN          NaN
# Other starches (edible)                                    0.0          0.0
# Sugar                                                      0.0          0.0
# Sweets (Candy, Chocolate)                                  0.0          0.0
# Honey (/Syrups, jams, marmalade, jellies, canne...         0.0          0.0
# Lentil, cooked / Peas (/Beans, lentils and othe...         0.5          0.0
# Groundnuts in shell/shelled                                0.3          0.0
# Coconuts (mature/immature)                                 0.0          0.0
# Cashew (Almonds and other nuts)                            0.1          0.0
# Sunflower seed / Seeds and products from nuts/s...         0.2          0.0
# Onion, raw (/tomatoes, carrots and green pepper...         0.1          0.0
# Spinach, cooked (/cabbage and other green veget...         0.2          0.0
# Amranth, leaves raw / Canned, dried and wild ve...         0.2          0.0
# Ripe Bananas                                               0.4          0.0
# Oranges (citrus fruits)                                    0.1          0.0
# Mangoes (other fruits)                                     0.1          0.0
# Sugarcane                                                  0.0          0.0
# Goat meat                                                  0.3          1.9
# Beef including minced sausage                              0.3          1.9
# Pork including sausages and bacon                          0.3          0.6
# Chicken and other poultry                                  0.2          0.2
# Wild birds and insects                                     NaN          NaN
# Cricket (Other domestic/wild meat products)                0.3          1.6
# Eggs                                                       0.4          8.1
# Raw Fresh fish and seafood (including dagaa)               0.3          1.1
# Dried/salted/canned fish and seafood (including...         7.3         35.0
# Fish                                                       0.5          0.0
# Fresh milk                                                 0.0          0.4
# Cream cheese (milk products)                               0.0          0.4
# Canned milk/milk powder                                    0.4          3.0
# Cooking oil (vegetable oil)                                0.0          0.0
# Butter refined - ghee                                      0.0          0.0
# Salt                                                       0.0          0.0
# Other spices                                               NaN          NaN
# Wheat flour (whole grain)                                  0.3          0.0
# Maida (wheat)                                              0.2          0.0
# Tea dry                                                    0.0          0.0
# Coffee and cocoa                                           0.0          0.0
# Other raw materials for drinks                             NaN          NaN
# Mango juice (soda, juice, water)                           0.1          0.0
# Instant coffee                                             0.0          0.0
# Bottled beer                                               0.1          0.0
# Local beer                                                 0.1          0.0
# Vinegar (Wine and spirits)                                 0.0          0.0

# %% [markdown]
# We need the index of the Food Conversion Table (FCT) to match up with
# the index of the vector of quantities demanded.   To manage this we
# make use of the `align` method for `pd.DataFrames`:

# %%
# Index of fct includes names of goods and also units.  Drop the latter:
try:
    fct.index = fct.index.droplevel('unit')
except AttributeError: pass # not a multiindex?

# Create a new FCT and vector of consumption that only share rows in common:
fct0,c0 = fct.align(c,axis=0,join='inner')   #align method is taking object fct and a series of demand c to make an inter join of two things
print(fct0.index)
# Out:
# Index(['Bread', 'Sugar', 'Ripe Bananas', 'Sugarcane', 'Eggs', 'Salt'], dtype='object')

# %% [markdown]
# Now, since rows of `fct0` and `c0` match, we can obtain nutritional
# outcomes from the inner (or dot, or matrix) product of the transposed
# `fct0` and `c0`:

# %%
# The @ operator means matrix multiply
N = fct0.T@c0   #TRANSPOSE FOOD CONVERSION TABLE  AND MULTIPLIED BY VECTOR OF DEMANDS
N  # N is the vector of nutritions.


#this is for household. #nutritional requirements is individual.
# Out:
# Protein         1358.838860
# Calories       89774.426810
# Calcium         4995.581293
# Iron             262.214340
# Zinc             206.706788
# Magnesium      21225.989987
# Vitamin A       2527.113721
# Vitamin E         71.652803
# Vitamin C       6146.206968
# Vitamin B6       282.785578
# Vitamin B12        4.077320
# dtype: float64

# %% [markdown]
# Of course, since we can compute the nutritional content of a vector of
# consumption goods `c0`, we can also use our demand functions to
# compute nutrition as a *function* of prices and budget.

# %%
def nutrient_demand(x,p):
    c = r.demands(x,p)
    fct0,c0 = fct.align(c,axis=0,join='inner')
    N = fct0.T@c0

    return N

# %% [markdown]
# With this `nutrient_demand` function in hand, we can see how nutrient
# outcomes vary with budget, given prices:

# %%
import numpy as np
import matplotlib.pyplot as plt
X = np.linspace(200,13000,2000)

UseNutrients = ['Protein','Calories','Zinc','Iron','Vitamin C','Calcium','Magnesium','Vitamin A','Vitamin E','Vitamin B6','Vitamin B12']

plt.plot(X,pd.concat({x:np.log(nutrient_demand(x,p))[UseNutrients] for x in X},axis=1).T)
plt.legend(UseNutrients)
plt.xlabel('Budget')
plt.ylabel('Log Nutrient')

#engel curve for diff nutritions.

# %% [markdown]
# Now how does nutrition vary with prices?

# %%
P = np.linspace(.1,13000,50)

x = p.loc["Mangoes, Avocadoes And Other Fruits"]

plt.plot(P,pd.concat({p0:np.log(nutrient_demand(x,my_prices(p0,i='Mangoes, Avocadoes And Other Fruits')))[UseNutrients] for p0 in P},axis=1).T)
plt.legend(UseNutrients)
plt.xlabel('Price')
plt.ylabel('log nutrient')


#as price increases, nutritional outcome decreases.

# %% [markdown]
# ## Nutritional requirements

# %% [markdown]
# Individuals have nutritional requirements established by nutrition
# scientists.  Here are some standards established by the Indian
# National Institute of Nutrition:

# %% [markdown]
# ### Nutritional needs of individuals

# %% [markdown]
# | Sex-Age|Calories|Protein|Fat|Calcium|Iron|Betacarotene|Thiamine|Riboflavin|Niacin|Ascorbic Acid|
# |---|---|---|---|---|---|---|---|---|---|---|
# | C 0-0.5||||500|||.2|.3||25|
# | C 0.5-1|||19|500|5|2800|.3|.4||25|
# | C 1-3|1060|16.7|27|600|9|3200|.5|.6|8|40|
# | C 4-6|1350|20.1|25|600|13|3200|.7|.8|11|40|
# | C 7-9|1690|29.5|30|600|16|4800|.8|1.|13|40|
# | B 10-12|2190|39.9|35|800|21|4800|1.1|1.3|15|40|
# | G 10-12|2010|40.4|35|800|27|4800|1.|1.2|13|40|
# | B 13-15|2750|54.3|45|800|32|4800|1.4|1.6|16|40|
# | G 13-15|2330|51.9|40|800|27|4800|1.2|1.4|14|40|
# | B 16-17|3020|61.5|50|800|28|4800|1.5|1.8|17|40|
# | G 16-17|2440|55.5|35|800|26|4800|1.|1.2|14|40|
# | M|2730|60|30|600|17|4800|1.4|1.4|18|40|
# | W|2230|55|25|1200|21|4800|1.1|1.3|14|40|

# %%
#rda=pd.DataFrame([x[1:] for x in RDA[1:]],columns=RDA[0][1:],index=[x[0] for x in RDA[1:]])
#rda.to_pickle('rda.df') #this does not work

# %% [markdown]
# ### Nutritional Needs of Households

# %% [markdown]
# Our data on demand and nutrients is at the *household* level; we
#    can&rsquo;t directly compare household level nutrition with individual
#    level requirements.  What we **can** do is add up minimum individual
#    requirements, and see whether household total exceed these.  This
#    isn&rsquo;t a guarantee that all individuals have adequate nutrition
#    (since the way food is allocated in the household might be quite
#    unequal, or unrelated to individual requirements), but it is
#    *necessary* if all individuals are to have adequate nutrition.
#
# For the average household in the Tanzanian villages, the number of
# different kinds of people can be computed by averaging over households:

# %%
# In 2008, averaged over households and villages
zbar = r.z.sel(t=2008).mean(['j','m'])[:-1]
zbar.to_dataframe()

# %% [markdown]
# Now, the inner/dot/matrix product between `zbar` and the `rda`
# DataFrame of requirements will give us

# %% [markdown]
# Minimum nutrition requirements for the
# average household:

# %%
rda = pd.read_pickle('TanzanianNPS/rda.df')


# This matrix product gives minimum nutrient requirements for average household in 2008
hh_rda = rda.replace('',0).T@zbar 
hh_rda

# %% [markdown]
# ## Nutritional Adequacy of Food Demands

# %% [markdown]
# Since we can trace out demands for nutrients as a function of $(x,p)$,
# and we&rsquo;ve computed minimum nutritional requirements for the average
# household, we can *normalize* nutritional intake to check the adequacy
# of diet.

# %%
def nutrient_adequacy_ratio(x,p):
    return nutrient_demand(x,p)/hh_rda  #vector of total nutrients divide by minimum household rda(nutrition req)
#if more than one, adequate. # if less than one, not adequate.
nutrient_adequacy_ratio(x,p)*1000000

# %% [markdown]
# In terms of normalized nutrients, any household with more than one
# unit of any given nutrient (or zero in logs) will be consuming a
# minimally adequate level of the nutrient; below this level there&rsquo;s
# clearly nutritional inadequacy.  For this reason the ratio of
# actual nutrients to required nutrients is termed the &ldquo;nutrient
# adequacy ratio,&rdquo; or NAR.

# %%
plt.plot(X,pd.concat({x:np.log(nutrient_adequacy_ratio(x,p))[UseNutrients] for x in X},axis=1).T)
plt.legend(UseNutrients)
plt.xlabel('Budget')
plt.ylabel('log nutrient adequacy ratio')
plt.axhline(0)

#if budget is greater than 30, it is more likely for households to meet minimum nutrition req. 


#calories per rupee - nutrient per rupee
#estimated demand system - need to know which food they prefer.

#need to look at demand elasticity.

# %% [markdown]
# As before, we can also vary relative prices.  Here we trace out
# nutritional adequacy varying the price of Bengalgram dahl:

# %%
x = p.loc["Mangoes, Avocadoes And Other Fruits"]

plt.plot(pd.concat({p0:np.log(nutrient_adequacy_ratio(x,my_prices(p0,i='Mangoes, Avocadoes And Other Fruits')))[UseNutrients] for p0 in P},axis=1).T,P)
plt.legend(UseNutrients)
plt.ylabel('Price')
plt.xlabel('log nutrient adequacy ratio')
plt.axvline(0)
plt.axhline(p.sel(i='Mangoes, Avocadoes And Other Fruits').values)

#lower right side is adequate nutriton. price. adequate protein, fat, iron, calcium. but calories deficient. 
#if we somehow lower price of dhal to 1, then we can get adequate nutrients.
#they are not going to eat just Dhal.

# %% [markdown]
# And varying the price of rice:

# %%
x = 280

plt.plot(pd.concat({p0:np.log(nutrient_adequacy_ratio(x,my_prices(p0,i='Ripe Bananas')))[UseNutrients] for p0 in P},axis=1).T,P)
plt.legend(UseNutrients)
plt.ylabel('Price')
plt.xlabel('log NAR')
plt.axvline(0)
plt.axhline(p.sel(i='Ripe Bananas').values)

#inelastic for rice demand. even as price changes, if we double it to 4 rupees, it doesnt change much.
#Rice is prob not a good choice to target for policy design since its inelastic
